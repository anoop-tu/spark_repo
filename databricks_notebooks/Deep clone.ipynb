# %%
# %sql
DROP TABLE IF EXISTS orders_managed;
CREATE OR REPLACE TABLE orders_managed (
order_id BIGINT,
sku STRING,
product_name STRING,
product_category STRING,
qty INT,
unit_price DECIMAL(10,2)
);

# %%
# %sql
ALTER TABLE orders_managed ADD CONSTRAINT valid_qty CHECK
(qty > 0);

# %%
# %sql
insert into orders_managed (order_id, sku, product_name, product_category, qty, unit_price) values (1, '12345', 'product1', 'category1', 10, 100.00), (2, '12346', 'product2', 'category2', 20, 200.00), (3, '12347', 'product3', 'category3', 30, 300.00), (4, '12348', 'product4', 'category4', 40, 400.00), (5, '12349', 'product5', 'category5', 50, 500.00), (6, '12350', 'product6', 'category6', 60, 600.00), (7, '12351', 'product7', 'category7', 70, 700.00), (8, '12352', 'product8', 'category8', 80, 800.00), (9, '12353', 'product9', 'category9', 90, 900.00)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>9</td><td>9</td></tr></tbody></table></div>

# %%
# %sql
insert into orders_managed (order_id, sku, product_name, product_category, qty, unit_price) values (1, '12354', 'product10', 'category10', 10, 100.00), (2, '12355', 'product20', 'category20', 20, 200.00)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
delete from orders_managed where order_id = 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

# %%
# %sql
update orders_managed set qty = 100 where order_id = 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

# %%
# %sql
select distinct _metadata.file_path from orders_managed
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>file_path</th></tr></thead><tbody><tr><td>abfss://unity-catalog-storage@dbstoragekf4btudtg6f2k.dfs.core.windows.net/7405613815916659/__unitystorage/catalogs/c81fd24d-dda0-4fd3-afe6-9159d22a76fa/tables/7f44f571-3f7d-4e31-bb66-58183444c97e/part-00000-74c8ebed-a9b9-4b9b-98e6-5b9985075903-c000.zstd.parquet</td></tr><tr><td>abfss://unity-catalog-storage@dbstoragekf4btudtg6f2k.dfs.core.windows.net/7405613815916659/__unitystorage/catalogs/c81fd24d-dda0-4fd3-afe6-9159d22a76fa/tables/7f44f571-3f7d-4e31-bb66-58183444c97e/part-00000-68ec0f75-b8b4-4fb9-afc5-b4a6e3f52b23-c000.zstd.parquet</td></tr></tbody></table></div>

# %%
# %sql
describe history orders_managed
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>7</td><td>2026-08-28T09:35:22Z</td><td>147836707444603</td><td>anooptu@gmail.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(4394494197812417)</td><td>0826-063441-ydade36q</td><td>6</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 2, numRemovedBytes -> 4722, p25FileSize -> 2376, numDeletionVectorsRemoved -> 1, minFileSize -> 2376, numAddedFiles -> 1, maxFileSize -> 2376, p75FileSize -> 2376, p50FileSize -> 2376, numAddedBytes -> 2376)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.13</td></tr><tr><td>6</td><td>2026-08-28T09:35:17Z</td><td>147836707444603</td><td>anooptu@gmail.com</td><td>UPDATE</td><td>Map(predicate -> ["(order_id#8830L = 2)"])</td><td>null</td><td>List(4394494197812417)</td><td>0826-063441-ydade36q</td><td>4</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 2221, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 2, numAddedChangeFiles -> 0, executionTimeMs -> 3931, conflictDetectionTimeMs -> 140, numDeletionVectorsUpdated -> 1, scanTimeMs -> 2224, numAddedFiles -> 1, numUpdatedRows -> 2, numAddedBytes -> 2340, rewriteTimeMs -> 1706)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.13</td></tr><tr><td>5</td><td>2026-08-28T09:35:16Z</td><td>147836707444603</td><td>anooptu@gmail.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(4394494197812417)</td><td>0826-063441-ydade36q</td><td>4</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 2, numRemovedBytes -> 4591, p25FileSize -> 2382, numDeletionVectorsRemoved -> 2, minFileSize -> 2382, numAddedFiles -> 1, maxFileSize -> 2382, p75FileSize -> 2382, p50FileSize -> 2382, numAddedBytes -> 2382)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.13</td></tr><tr><td>4</td><td>2026-08-28T09:35:11Z</td><td>147836707444603</td><td>anooptu@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(order_id#8102L = 1)"])</td><td>null</td><td>List(4394494197812417)</td><td>0826-063441-ydade36q</td><td>3</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 2, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 1611, numDeletionVectorsUpdated -> 0, numDeletedRows -> 2, scanTimeMs -> 881, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 730)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.13</td></tr><tr><td>3</td><td>2026-08-28T09:35:08Z</td><td>147836707444603</td><td>anooptu@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(4394494197812417)</td><td>0826-063441-ydade36q</td><td>2</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 2, numOutputBytes -> 2221)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.13</td></tr><tr><td>2</td><td>2026-08-28T09:35:06Z</td><td>147836707444603</td><td>anooptu@gmail.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(4394494197812417)</td><td>0826-063441-ydade36q</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 9, numOutputBytes -> 2370)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.13</td></tr><tr><td>1</td><td>2026-08-28T09:35:04Z</td><td>147836707444603</td><td>anooptu@gmail.com</td ...

# %%
# %sql
drop table if exists orders_managed_dclone

# %%
# %sql
create or replace table orders_managed_dclone deep clone orders_managed;
describe detail  orders_managed_dclone;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th><th>clusterByAuto</th></tr></thead><tbody><tr><td>delta</td><td>02f2ff5e-c296-45fd-89b6-1ed064babda6</td><td>useastws.default.orders_managed_dclone</td><td>null</td><td>abfss://unity-catalog-storage@dbstoragekf4btudtg6f2k.dfs.core.windows.net/7405613815916659/__unitystorage/catalogs/c81fd24d-dda0-4fd3-afe6-9159d22a76fa/tables/870ef999-4e99-4df2-aa2e-b167cd5deb77</td><td>2026-08-28T09:35:01.975Z</td><td>2026-08-28T09:35:52Z</td><td>List()</td><td>List()</td><td>1</td><td>2376</td><td>Map(delta.parquet.compression.codec -> zstd, delta.enableDeletionVectors -> true, delta.constraints.valid_qty -> qty > 0)</td><td>3</td><td>7</td><td>List(appendOnly, checkConstraints, deletionVectors, invariants)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
select distinct _metadata.file_path from orders_managed_dclone
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>file_path</th></tr></thead><tbody><tr><td>abfss://unity-catalog-storage@dbstoragekf4btudtg6f2k.dfs.core.windows.net/7405613815916659/__unitystorage/catalogs/c81fd24d-dda0-4fd3-afe6-9159d22a76fa/tables/870ef999-4e99-4df2-aa2e-b167cd5deb77/part-00000-96c81ca1-a331-4e52-8e49-500ffcab3cd8-c000.zstd.parquet</td></tr></tbody></table></div>

# %%
# %sql
select * from orders_managed_dclone
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>sku</th><th>product_name</th><th>product_category</th><th>qty</th><th>unit_price</th></tr></thead><tbody><tr><td>2</td><td>12346</td><td>product2</td><td>category2</td><td>100</td><td>200.00</td></tr><tr><td>2</td><td>12355</td><td>product20</td><td>category20</td><td>100</td><td>200.00</td></tr><tr><td>3</td><td>12347</td><td>product3</td><td>category3</td><td>30</td><td>300.00</td></tr><tr><td>4</td><td>12348</td><td>product4</td><td>category4</td><td>40</td><td>400.00</td></tr><tr><td>5</td><td>12349</td><td>product5</td><td>category5</td><td>50</td><td>500.00</td></tr><tr><td>6</td><td>12350</td><td>product6</td><td>category6</td><td>60</td><td>600.00</td></tr><tr><td>7</td><td>12351</td><td>product7</td><td>category7</td><td>70</td><td>700.00</td></tr><tr><td>8</td><td>12352</td><td>product8</td><td>category8</td><td>80</td><td>800.00</td></tr><tr><td>9</td><td>12353</td><td>product9</td><td>category9</td><td>90</td><td>900.00</td></tr></tbody></table></div>

# %%
# %sql
insert into orders_managed (order_id, sku, product_name, product_category, qty, unit_price) values (101, '12354', 'product10', 'category10', 10, 100.00), (201, '12355', 'product20', 'category20', 20, 200.00)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
describe history orders_managed_dclone
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>0</td><td>2026-08-28T09:35:52Z</td><td>147836707444603</td><td>anooptu@gmail.com</td><td>CLONE</td><td>Map(source -> useastws.default.orders_managed, sourceVersion -> 7, isShallow -> false)</td><td>null</td><td>List(4394494197812417)</td><td>0826-063441-ydade36q</td><td>-1</td><td>Serializable</td><td>false</td><td>Map(removedFilesSize -> 0, numRemovedFiles -> 0, sourceTableSize -> 2376, numCopiedFiles -> 1, copiedFilesSize -> 2376, sourceNumOfFiles -> 1)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.13</td></tr></tbody></table></div>

# %% [markdown]
# Data file of the source table for the latest version is copied over to target deep clone table.

# %%
# %sql
drop table orders_ctas;
create table orders_ctas as (
    select * from orders_managed
);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from orders_ctas
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>sku</th><th>product_name</th><th>product_category</th><th>qty</th><th>unit_price</th></tr></thead><tbody><tr><td>2</td><td>12346</td><td>product2</td><td>category2</td><td>100</td><td>200.00</td></tr><tr><td>2</td><td>12355</td><td>product20</td><td>category20</td><td>100</td><td>200.00</td></tr><tr><td>3</td><td>12347</td><td>product3</td><td>category3</td><td>30</td><td>300.00</td></tr><tr><td>4</td><td>12348</td><td>product4</td><td>category4</td><td>40</td><td>400.00</td></tr><tr><td>5</td><td>12349</td><td>product5</td><td>category5</td><td>50</td><td>500.00</td></tr><tr><td>6</td><td>12350</td><td>product6</td><td>category6</td><td>60</td><td>600.00</td></tr><tr><td>7</td><td>12351</td><td>product7</td><td>category7</td><td>70</td><td>700.00</td></tr><tr><td>8</td><td>12352</td><td>product8</td><td>category8</td><td>80</td><td>800.00</td></tr><tr><td>9</td><td>12353</td><td>product9</td><td>category9</td><td>90</td><td>900.00</td></tr><tr><td>101</td><td>12354</td><td>product10</td><td>category10</td><td>10</td><td>100.00</td></tr><tr><td>201</td><td>12355</td><td>product20</td><td>category20</td><td>20</td><td>200.00</td></tr></tbody></table></div>

# %%
# %sql
describe history orders_ctas
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>0</td><td>2026-08-28T09:36:30Z</td><td>147836707444603</td><td>anooptu@gmail.com</td><td>CREATE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true"}, statsOnLoad -> false)</td><td>null</td><td>List(4394494197812417)</td><td>0826-063441-ydade36q</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 2, numOutputRows -> 11, numOutputBytes -> 4596)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.13</td></tr></tbody></table></div>

# %%
# %sql
select distinct _metadata.file_path from orders_ctas
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>file_path</th></tr></thead><tbody><tr><td>abfss://unity-catalog-storage@dbstoragekf4btudtg6f2k.dfs.core.windows.net/7405613815916659/__unitystorage/catalogs/c81fd24d-dda0-4fd3-afe6-9159d22a76fa/tables/f96e8604-f17b-4ef3-86e7-e10259e0bf7b/part-00000-9b77eaad-8303-45df-8b97-e5818c0638f9-c000.zstd.parquet</td></tr><tr><td>abfss://unity-catalog-storage@dbstoragekf4btudtg6f2k.dfs.core.windows.net/7405613815916659/__unitystorage/catalogs/c81fd24d-dda0-4fd3-afe6-9159d22a76fa/tables/f96e8604-f17b-4ef3-86e7-e10259e0bf7b/part-00001-a9da2521-9ebd-47fa-8a00-2c22b77b5d2d-c000.zstd.parquet</td></tr></tbody></table></div>

# %%
# %sql
describe formatted orders_managed
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>order_id</td><td>bigint</td><td>null</td></tr><tr><td>sku</td><td>string</td><td>null</td></tr><tr><td>product_name</td><td>string</td><td>null</td></tr><tr><td>product_category</td><td>string</td><td>null</td></tr><tr><td>qty</td><td>int</td><td>null</td></tr><tr><td>unit_price</td><td>decimal(10,2)</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>unit_price, product_name, qty, product_category, order_id, sku</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>useastws</td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>orders_managed</td><td></td></tr><tr><td>Created Time</td><td>Fri Aug 28 09:35:02 UTC 2026</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>abfss://unity-catalog-storage@dbstoragekf4btudtg6f2k.dfs.core.windows.net/7405613815916659/__unitystorage/catalogs/c81fd24d-dda0-4fd3-afe6-9159d22a76fa/tables/7f44f571-3f7d-4e31-bb66-58183444c97e</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>anooptu@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_eastus)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.constraints.valid_qty=qty > 0,delta.enableDeletionVectors=true,delta.feature.appendOnly=supported,delta.feature.checkConstraints=supported,delta.feature.deletionVectors=supported,delta.feature.invariants=supported,delta.minReaderVersion=3,delta.minWriterVersion=7,delta.parquet.compression.codec=zstd]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# Constraints on the source table didnt get copied to ctas table. but in deep clone it was copied

# %%
# %sql
describe formatted orders_ctas
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>order_id</td><td>bigint</td><td>null</td></tr><tr><td>sku</td><td>string</td><td>null</td></tr><tr><td>product_name</td><td>string</td><td>null</td></tr><tr><td>product_category</td><td>string</td><td>null</td></tr><tr><td>qty</td><td>int</td><td>null</td></tr><tr><td>unit_price</td><td>decimal(10,2)</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>unit_price, product_name, qty, product_category, order_id, sku</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>useastws</td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>orders_ctas</td><td></td></tr><tr><td>Created Time</td><td>Fri Aug 28 09:36:30 UTC 2026</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>abfss://unity-catalog-storage@dbstoragekf4btudtg6f2k.dfs.core.windows.net/7405613815916659/__unitystorage/catalogs/c81fd24d-dda0-4fd3-afe6-9159d22a76fa/tables/f96e8604-f17b-4ef3-86e7-e10259e0bf7b</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>anooptu@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_eastus)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.invariants=supported,delta.minReaderVersion=3,delta.minWriterVersion=7,delta.parquet.compression.codec=zstd]</td><td></td></tr></tbody></table></div>
