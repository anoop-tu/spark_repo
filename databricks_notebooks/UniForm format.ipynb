# %% [markdown]
# Enable 3 tblproperties for UniForm
# ('delta.columnMapping.mode'='name','delta.enableIcebergCompatV2' = 'true',
# 'delta.universalFormat.enabledFormats' = 'iceberg')

# %%
# %sql
DROP TABLE IF EXISTS orders_managed;
CREATE OR REPLACE TABLE orders_managed (
order_id BIGINT,
sku STRING,
product_name STRING,
product_category STRING,
qty INT,
unit_price DECIMAL(10,2)
)TBLPROPERTIES ('delta.columnMapping.mode'='name','delta.enableIcebergCompatV2' = 'true',
'delta.universalFormat.enabledFormats' = 'iceberg')

# %%
# %sql
insert into orders_managed (order_id, sku, product_name, product_category, qty, unit_price) values (1, '12345', 'product1', 'category1', 10, 100.00), (2, '12346', 'product2', 'category2', 20, 200.00), (3, '12347', 'product3', 'category3', 30, 300.00), (4, '12348', 'product4', 'category4', 40, 400.00), (5, '12349', 'product5', 'category5', 50, 500.00), (6, '12350', 'product6', 'category6', 60, 600.00), (7, '12351', 'product7', 'category7', 70, 700.00), (8, '12352', 'product8', 'category8', 80, 800.00), (9, '12353', 'product9', 'category9', 90, 900.00)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>9</td><td>9</td></tr></tbody></table></div>

# %%
# %sql
describe formatted orders_managed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>order_id</td><td>bigint</td><td>null</td></tr><tr><td>sku</td><td>string</td><td>null</td></tr><tr><td>product_name</td><td>string</td><td>null</td></tr><tr><td>product_category</td><td>string</td><td>null</td></tr><tr><td>qty</td><td>int</td><td>null</td></tr><tr><td>unit_price</td><td>decimal(10,2)</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>col-fc3e65e9-b677-4c32-a342-b6e431c721f0, col-b9480f4c-4d2f-409a-ba12-dcac78384b59, col-2a9c092f-8a7b-460d-8aea-d67d9d96e061, col-38342290-8246-48eb-b20f-b30a22930417, col-a926cbeb-f9d2-4f9b-a87c-7a87e9522124, col-2566e21e-a8e5-4871-b7e3-0ebd19265cc9</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Uniform Iceberg</td><td></td><td></td></tr><tr><td>Metadata location</td><td>abfss://unity-catalog-storage@dbstoragekf4btudtg6f2k.dfs.core.windows.net/7405613815916659/__unitystorage/catalogs/c81fd24d-dda0-4fd3-afe6-9159d22a76fa/tables/dd88f127-b686-48cb-8e1e-c4478d7c8648/metadata/00001-0d7943d3-3466-4af1-8d41-0a95b53814a5.metadata.json</td><td></td></tr><tr><td>Converted delta version</td><td>1</td><td></td></tr><tr><td>Converted delta timestamp</td><td>2026-08-28T10:20:51.845615379Z</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>useastws</td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>orders_managed</td><td></td></tr><tr><td>Created Time</td><td>Fri Aug 28 10:16:49 UTC 2026</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>abfss://unity-catalog-storage@dbstoragekf4btudtg6f2k.dfs.core.windows.net/7405613815916659/__unitystorage/catalogs/c81fd24d-dda0-4fd3-afe6-9159d22a76fa/tables/dd88f127-b686-48cb-8e1e-c4478d7c8648</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>anooptu@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_eastus)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.columnMapping.maxColumnId=6,delta.columnMapping.mode=name,delta.enableIcebergCompatV2=true,delta.feature.appendOnly=supported,delta.feature.columnMapping=supported,delta.feature.icebergCompatV2=supported,delta.feature.invariants=supported,delta.minReaderVersion=2,delta.minWriterVersion=7,delta.parquet.compression.codec=zstd,delta.universalFormat.enabledFormats=iceberg]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# Meta data for iceberg is created in a separate folder along with delta metadata in separate folder
