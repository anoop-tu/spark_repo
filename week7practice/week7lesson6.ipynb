# %%
from pyspark.sql import SparkSession

spark = SparkSession. \
builder. \
appName("week7-lesson-5"). \
config("spark.sql.warehouse.dir", f"/user/itv024128/warehouse"). \
enableHiveSupport(). \
master('yarn'). \
getOrCreate()
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
spark.sql("use itv024128")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql(" drop table itv024128.orders1GB_ext ")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql(" create table itv024128.orders1GB_ext ( order_id long, order_date string , cust_id long, status string) using csv location '/user/itv024128/orders_wh' ")
# Out:
# ++
# ||
# ++
# ++

# %%
## spark.sql(" create table itv024128.orders1GB_ext ( order_id long, order_date string , cust_id long, status string) using csv location '/user/itv024128/orders_wh' ")

# %%
spark.sql("show tables")
# Out:
# +---------+------------------+-----------+
# | database|         tableName|isTemporary|
# +---------+------------------+-----------+
# |itv024128|         groceries|      false|
# |itv024128|     groceries_ext|      false|
# |itv024128|groceries_ext_json|      false|
# |itv024128|    groceries_json|      false|
# |itv024128|         orders1gb|      false|
# |itv024128|     orders1gb_ext|      false|
# |itv024128|        orders_ext|      false|
# +---------+------------------+-----------+

# %% [markdown]
# ### Manually added a new file to the external location of the table - hadoop fs -cp /user/itv024128/orders_wh/part-00000-a09796af-757d-4714-b6fb-f3165a835645-c000.csv /user/itv024128/orders_wh/orders_wh1.csv

# %%
spark.sql("select count(*) from itv024128.orders1GB_ext")
# Out:
# +--------+
# |count(1)|
# +--------+
# |   68884|
# +--------+

# %%
spark.sql("refresh table itv024128.orders1GB_ext")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("select count(*) from itv024128.orders1GB_ext")
# Out:
# +--------+
# |count(1)|
# +--------+
# |  137768|
# +--------+

# %% [markdown]
# ### Manually remove a  file to the external location of the table

# %%
spark.sql("select count(*) from itv024128.orders1GB_ext")
# Out:
# +--------+
# |count(1)|
# +--------+
# |   68884|
# +--------+

# %% [markdown]
# #### When ever back end data changes, we have to refresh the table to fetch the new data. If we delete data from backend the next query might even fail with file not found. we need to run refresh table to fetch latest status

# %%
spark.sql("cache table itv024128.orders1GB_ext")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("select count(*) from itv024128.orders1GB_ext")
# Out:
# +--------+
# |count(1)|
# +--------+
# |   68884|
# +--------+

# %%
## change back end data

# %%
spark.sql("refresh table itv024128.orders1GB_ext")
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("select count(*) from itv024128.orders1GB_ext")
# Out:
# +--------+
# |count(1)|
# +--------+
# |   68884|
# +--------+
