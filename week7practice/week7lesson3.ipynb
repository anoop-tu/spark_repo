# %%
from pyspark.sql import SparkSession

spark = SparkSession. \
builder. \
appName("week7-lesson-3"). \
config("spark.sql.warehouse.dir", f"/user/itv024128/warehouse"). \
enableHiveSupport(). \
master('yarn'). \
getOrCreate()
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
#order = 'order_id long , order_date date , cust_id long, status string'

# %%
orderSchema = StructType([
    StructField("order_id",LongType()),
    StructField("order_date",DateType()),
    StructField("cust_id",LongType()),
    StructField("status",StringType()),
])

# %%
df1 = spark.read.schema(orderSchema).option("header","false").csv('/public/trendytech/orders/orders_1gb.csv')

# %%
df1.show(4)
# Out:
# +--------+----------+-------+---------------+
# |order_id|order_date|cust_id|         status|
# +--------+----------+-------+---------------+
# |       1|2013-07-25|  11599|         CLOSED|
# |       2|2013-07-25|    256|PENDING_PAYMENT|
# |       3|2013-07-25|  12111|       COMPLETE|
# |       4|2013-07-25|   8827|         CLOSED|
# +--------+----------+-------+---------------+
# only showing top 4 rows

# %%
df1.count()
# Out:
# 25831125

# %%
df1.distinct().count()
# Out:
# 68883

# %%
cached_df = df1.cache()

# %%
cached_df.count()
# Out:
# 25831125

# %%
cached_df.distinct().count() ## runs much faster that the previous distince count as the df is cached
# Out:
# 68883

# %%
df1.count() # also hits the cache
# Out:
# 25831125
