# %%
from pyspark.sql import SparkSession
import getpass
username = getpass.getuser()
spark = SparkSession. \
builder. \
appName("repartition"). \
config('spark.ui.port','0'). \
config("spark.sql.warehouse.dir", f"/user/itv024128/warehouse"). \
enableHiveSupport(). \
master('yarn'). \
getOrCreate()

# %%
orders_rdd = spark.sparkContext.textFile("/public/trendytech/orders/orders_1gb.csv")

# %%
orders_rdd.getNumPartitions()
# Out:
# 9

# %%
orders_rdd.count()
# Out:
# 25831125

# %%
repart_rdd = orders_rdd.repartition(15)

# %%
repart_rdd.getNumPartitions()
# Out:
# 15

# %%
repart_rdd.count()
# Out:
# 25831125

# %%
repart_rdd1 = orders_rdd.repartition(5)

# %%
repart_rdd1.getNumPartitions()
# Out:
# 5

# %%
repart_rdd1.count()
# Out:
# 25831125

# %%
repart_rdd2 = orders_rdd.repartition(25)

# %%
repart_rdd2.count()
# Out:
# 25831125

# %%
coalesce_rdd = repart_rdd2.coalesce(9)

# %%
coalesce_rdd.count()
# Out:
# 25831125

# %%
coalesce_rdd.getNumPartitions()
# Out:
# 9
